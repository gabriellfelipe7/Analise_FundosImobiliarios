# %% [markdown]
# # Análise de Dados Financeiros - Fundos Imobiliários

# %%
#BIBLIOTECAS
import pandas as pd
from datetime import datetime, timedelta
import pyodbc
import getpass
import numpy as np
import importlib.util
import sys
import os

#CORES
RED   = "\033[1;31m"  
BLUE  = "\033[1;34m"
CYAN  = "\033[1;36m"
GREEN = "\033[0;32m"
RESET = "\033[0;0m"
BOLD    = "\033[;1m"
REVERSE = "\033[;7m"


# Caminho para o arquivo do seu programa
programa_path = 'C:/Users/C10446Q/Desktop/Gabriel/Projetos/credz.py'

# Carrega o módulo
# spec = importlib.util.spec_from_file_location("credz.py", programa_path)
# credz = importlib.util.module_from_spec(spec)
# sys.modules["credz.py"] = credz
# spec.loader.exec_module(credz)

# driver =  '{ODBC Driver 17 for SQL Server}'
# conn_azure = pyodbc.connect('DRIVER='+driver+';SERVER=tcp:'+credz.server_prod+';PORT=1433;DATABASE='+credz.database_prod+';UID='+credz.username+';PWD='+ '{' + credz.password + '}' + ';Encrypt=yes;TrustServerCertificate=no;loginTimeout=5;Authentication=ActiveDirectoryPassword')

# %%
# Lista todos os arquivos na pasta
arquivos = os.listdir()

# Filtra apenas arquivos (exclui subpastas)
arquivos = [f for f in arquivos if os.path.isfile(os.path.join(pasta, f))]


lista_arquivos = []

for k in arquivos:
    lista_arquivos.append(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       2 arquivos = os.listdir()
#       4 # Filtra apenas arquivos (exclui subpastas)
# ----> 5 arquivos = [f for f in arquivos if os.path.isfile(os.path.join(pasta, f))]
#       8 lista_arquivos = []
#      10 for k in arquivos:
#
# Cell In[9], line 5, in <listcomp>(.0)
#       2 arquivos = os.listdir()
#       4 # Filtra apenas arquivos (exclui subpastas)
# ----> 5 arquivos = [f for f in arquivos if os.path.isfile(os.path.join(pasta, f))]
#       8 lista_arquivos = []
#      10 for k in arquivos:
#
# NameError: name 'pasta' is not defined

# %%
pd.read_parquet('FundosImobiliarios.parquet')
# Out:
#        id            cnpj                                               nome  \
# 0       1  05437916000127          FUNDO DE INVESTIMENTO IMOBILIÁRIO EUROPAR
# 1       2  03251720000118  FUNDO DE INVESTIMENTO IMOBILIÁRIO PROJETO ÁGUA...
# 2       3  01633741000172  FUNDO DE INVESTIMENTO IMOBILIÁRIO MEMORIAL OFFICE
# 3       4  14217108000145  FUNDO DE INVESTIMENTO IMOBILIÁRIO INDUSTRIAL D...
# 4       5  14721889000100  FUNDO DE INVESTIMENTO IMOBILIARIO POLO SHOPPIN...
# ..    ...             ...                                                ...
# 940  1011  47085640000105                                       JAI IV - FII
# 941  1012  49489928000170  051 AGRO FAZ III FDO INV NAS CAD PROD AGRO - F...
# 942  1013  48565175000172  051 AGRO FAZENDAS II FI NAS CANDEIAS PRODUTIVA...
# 943  1014  44527494000132  ARX DOVER RECEBÍVEIS FUNDO DE INVESTIMENTO IMO...
# 944  1015  48964604000184          GRIFFIN FUNDO DE INVESTIMENTO IMOBILIARIO
#
# ...
